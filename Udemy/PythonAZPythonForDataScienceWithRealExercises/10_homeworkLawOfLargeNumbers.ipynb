# %%
#the Law of Large Numbers
#LLN
#

import math
import numpy as np
from numpy.random import randn

N = 100
counter = 0

for i in randn(N):
    if i > -1 and i < 1:
        counter = counter + 1
answer = counter / N
print(answer)
# Out:
# 0.69

# %%
N = 10000
counter = 0

for i in randn(N):
    if i > -1 and i < 1:
        counter = counter + 1
print(counter / N)
# Out:
# 0.6823
