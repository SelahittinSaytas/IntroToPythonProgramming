# %%
import pandas as pd
#One of the best Python package for working with 'Data Frames'
#Data Frames are a step up matrices - similar to tables
#Perfect structure for working with data sets

# %%
#Method 1: Specify Full Path To File

# %%
#Windows:
##stats = pd.read_csv("C:\\Users\\Kirill\\Desktop\\Python Programming Course\\DemographicData.csv")

#Mac:
stats= = pd.read_csv("/Users/selahittinsaytas/Documents/IntroToPythonProgramming/Udemy/PythonAZPythonForDataScienceWithRealExercises/DemographicData.csv")

stats
# Out:
#   File "<ipython-input-3-d09d862796ad>", line 5
#     stats= = pd.read_csv("/Users/selahittinsaytas/Documents/IntroToPythonProgramming/Udemy/PythonAZPythonForDataScienceWithRealExercises/DemographicData.csv")
#            ^
# SyntaxError: invalid syntax

# %%
#Method 3: Change Working Directory

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/selahittinsaytas/Documents/IntroToPythonProgramming/Udemy/PythonAZPythonForDataScienceWithRealExercises

# %%
#Windows:
#os.chdir("C:\\Users\\Kirill\\Desktop)

#Mac:
os.chdir("/Users/selahittinsaytas/Documents/IntroToPythonProgramming/Udemy/PythonAZPythonForDataScienceWithRealExercises")

# %%
print(os.getcwd())
# Out:
# /Users/selahittinsaytas/Documents/IntroToPythonProgramming/Udemy/PythonAZPythonForDataScienceWithRealExercises

# %%
stats2 = pd.read_csv("DemographicData.csv")

# %%
stats2
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#Exploring Your Data

# %%
#1- Full Data Frame
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /Users/selahittinsaytas/Documents/IntroToPythonProgramming/Udemy/PythonAZPythonForDataScienceWithRealExercises

# %%
stats2
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#2- Number of Rows
len(stats2) #195 rows imported
# Out:
# 195

# %%
#3- See Columns
stats2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#4- Number of Columns
len(stats2.columns) #5 columns imported
# Out:
# 5

# %%
#5- Top Rows
stats2.head() #Remember the brackets
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2.head(7)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
#6- Bottom Rows
stats2.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats2.tail(7)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 188  West Bank and Gaza          PSE      30.394            46.6
# 189               Samoa          WSM      26.172            15.3
# 190         Yemen, Rep.          YEM      32.947            20.0
# 191        South Africa          ZAF      20.850            46.5
# 192    Congo, Dem. Rep.          COD      42.394             2.2
# 193              Zambia          ZMB      40.471            15.4
# 194            Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#7 Information on The Columns
stats2.info() #Like the 'str()' function in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8 Get 'stats' on The Columns
stats2.describe() #Like summary function in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats2.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
#Renaming Columns of A Dataframe

# %%
stats2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats2.columns = ['CountryName','CountryCode',\
                  'BirthRate','InternetUsers','IncomeGroup']

# %%
stats2.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Subsetting Dataframes in Pandas
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# 3 prarts. Buckle up!
# How to subset 'rows'
# How to subset 'columns'
# Combine the two

# %%
#Part 1 - Rows
stats2[100:110]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 100             Libya         LBY     21.425        16.5000
# 101         St. Lucia         LCA     15.430        46.2000
# 102     Liechtenstein         LIE      9.200        93.8000
# 103         Sri Lanka         LKA     17.863        21.9000
# 104           Lesotho         LSO     28.738         5.0000
# 105         Lithuania         LTU     10.100        68.4529
# 106        Luxembourg         LUX     11.300        93.7765
# 107            Latvia         LVA     10.200        75.2344
# 108  Macao SAR, China         MAC     11.256        65.8000
# 109           Morocco         MAR     21.023        56.0000
#
#              IncomeGroup
# 100  Upper middle income
# 101  Upper middle income
# 102          High income
# 103  Lower middle income
# 104  Lower middle income
# 105          High income
# 106          High income
# 107          High income
# 108          High income
# 109  Lower middle income

# %%
stats2[:]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
stats2[185:]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
# 189                  Samoa         WSM     26.172           15.3
# 190            Yemen, Rep.         YEM     32.947           20.0
# 191           South Africa         ZAF     20.850           46.5
# 192       Congo, Dem. Rep.         COD     42.394            2.2
# 193                 Zambia         ZMB     40.471           15.4
# 194               Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# ...

# %%
stats2[:10] #The same as 'stats2.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
#Quick exercise (refresher)
#Reverse the dataframe
stats2[::-1]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 194                        Zimbabwe         ZWE     35.715       18.50000
# 193                          Zambia         ZMB     40.471       15.40000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 191                    South Africa         ZAF     20.850       46.50000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 189                           Samoa         WSM     26.172       15.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 187                         Vanuatu         VUT     26.739       11.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# ...

# %%
#Quick exercise (refresher)
#Get only every 20th row
stats2[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
#Part 2 - Columns
stats2.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2['CountryName']
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %%
stats2['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
stats2[['CountryName', 'BirthRate']].head() #In R, you'd be be passin a Vector: c('CountryName','BirthRateve')
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
stats2[["BirthRate","CountryName"]].head()
# Out:
#    BirthRate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
#Quick access - requires the name to be one word
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2.BirthRate.head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
#Part 3 - Combining The Two
stats2[4:8][["CountryName","BirthRate"]]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
df1 = stats2[4:8]
df1[["CountryName","BirthRate"]]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
df2 = stats2[["CountryName","BirthRate"]]
df2[4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
#Basic Operations With Dataframes

# %%
#Already spoke about subsetting. Refresh:
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2[["CountryCode","BirthRate","InternetUsers"]][4:8]
# Out:
#   CountryCode  BirthRate  InternetUsers
# 4         ARE     11.044           88.0
# 5         ARG     17.716           59.9
# 6         ARM     13.308           41.9
# 7         ATG     16.447           63.4

# %%
stats2.BirthRate[4:8]
# Out:
# 4    11.044
# 5    17.716
# 6    13.308
# 7    16.447
# Name: BirthRate, dtype: float64

# %%
#Mathematical Operations:
result = stats2.BirthRate * stats2.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
#Adding a  column:
stats2["MyCalc"]=stats2.BirthRate*stats2.InternetUsers

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats2.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    MyCalc
# 190  Lower middle income  658.9400
# 191  Upper middle income  969.5250
# 192           Low income   93.2668
# 193  Lower middle income  623.2534
# 194           Low income  660.7275

# %%
#Comparison to R

# %%
stats2["xyz"]=[1,2,3,4,5] #Error. No recycling option
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-594a149d52d8> in <module>()
# ----> 1 stats2["xyz"]=[1,2,3,4,5] #Error. No recycling option
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2664
#    2665             # turn me into an ndarray
# ...

# %%
#Removing a column
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats2 = stats2.drop("MyCalc",1) #Or can be written as 'stats2.drop("MyCalc", axis=1)'

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Filtering Data Frames
#Filtering is about rows

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2.InternetUsers<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter = stats2.InternetUsers<2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats2[30:40]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 30         Canada         CAN     10.900          85.80          High income
# 31    Switzerland         CHE     10.200          86.34          High income
# 32          Chile         CHL     13.385          66.50          High income
# 33          China         CHN     12.100          45.80  Upper middle income
# 34  Cote d'Ivoire         CIV     37.320           8.40  Lower middle income
# 35       Cameroon         CMR     37.236           6.40  Lower middle income
# 36    Congo, Rep.         COG     37.011           6.60  Lower middle income
# 37       Colombia         COL     16.076          51.70  Upper middle income
# 38        Comoros         COM     34.326           6.50           Low income
# 39     Cabo Verde         CPV     21.625          37.50  Lower middle income

# %%
stats2[Filter] #Conceptually, this is just like R
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
#Awesome! Let's use this in practice now:
Filter2 = stats2.BirthRate>40

# %%
stats2[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats2[stats2.BirthRate>40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
#Even more interesting
stats2[stats2.BirthRate>40 and stats2.InternetUsers<2] #Error. Why?!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-8698e41b1b17> in <module>()
#       1 #Even more interesting
# ----> 2 stats2[stats2.BirthRate>40 and stats2.InternetUsers<2] #Error. Why?!
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats2.BirthRate>40 and stats2.InternetUsers<2 #Error. Why?!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-3ed57c43ee10> in <module>()
# ----> 1 stats2.BirthRate>40 and stats2.InternetUsers<2 #Error. Why?!
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Filter and Filter2 #Error. Why?!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-8696e154eae4> in <module>()
# ----> 1 Filter and Filter2 #Error. Why?!
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Filter & Filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
stats2[Filter & Filter2]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats2[(stats2.BirthRate>40) & (stats2.InternetUsers<2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
#Another One:
stats2[stats2.IncomeGroup == "High income"]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244       78.90000  High income
# 4     United Arab Emirates         ARE     11.044       88.00000  High income
# 5                Argentina         ARG     17.716       59.90000  High income
# 7      Antigua and Barbuda         ATG     16.447       63.40000  High income
# 8                Australia         AUS     13.200       83.00000  High income
# 9                  Austria         AUT      9.400       80.61880  High income
# 12                 Belgium         BEL     11.200       82.17020  High income
# 17                 Bahrain         BHR     15.040       90.00004  High income
# 18            Bahamas, The         BHS     15.339       72.00000  High income
# 22                 Bermuda         BMU     10.400       95.30000  High income
# 25                Barbados         BRB     12.188       73.00000  High income
# ...

# %%
#How to get the unique categories
stats2.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats2.BirthRate.unique()
# Out:
# array([ 10.244,  35.253,  45.985,  12.877,  11.044,  17.716,  13.308,
#         16.447,  13.2  ,   9.4  ,  18.3  ,  44.151,  11.2  ,  36.44 ,
#         40.551,  20.142,   9.2  ,  15.04 ,  15.339,   9.062,  12.5  ,
#         23.092,  10.4  ,  24.236,  14.931,  12.188,  16.405,  18.134,
#         25.267,  34.076,  10.9  ,  10.2  ,  13.385,  12.1  ,  37.32 ,
#         37.236,  37.011,  16.076,  34.326,  21.625,  15.022,  11.436,
#          8.5  ,  25.486,  10.   ,  21.198,  24.738,  21.07 ,  28.032,
#         34.8  ,   9.1  ,  10.3  ,  32.925,  10.7  ,  20.463,  12.3  ,
#         23.511,  30.555,  12.2  ,  13.332,  33.131,  37.337,  42.525,
#         37.503,  35.362,  19.334,  14.5  ,  27.465,  17.389,  18.885,
#          7.9  ,  21.593,  25.345,  20.297,  20.291,  15.   ,  17.9  ,
#         31.093,  13.4  ,  21.3  ,  13.54 ,  27.046,   8.2  ,  22.73 ,
#         35.194,  27.2  ,  24.462,  29.044,   8.6  ,  20.575,  27.051,
# ...

# %%
#Quick Exercise:
#Find out everything about Malta from this data set
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2[stats2.CountryName == "Malta"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
#Accessing individual elements

# %%
stats2[2,2] #Error! Why?!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: (2, 2)
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#'.at()' - For label. Important: Even integers are treated as labels
#'.iat()' - For integer location.
stats2.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats2.iat[0,1]
# Out:
# 'ABW'

# %%
stats2.at[2,"BirthRate"]
# Out:
# 45.984999999999999

# %%
#Why we need '.at()':
sub10=stats2[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,"CountryName"]
# Out:
# 'Azerbaijan'

# %%
#Introduction to Seaborn
#'seaborn package' is a very powerful visiulization package for Python
#'seaborn' builds on top of 'matplotlib'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
###Graph gets plotted in our jupyter notebook
plt.rcParams["figure.figsize"]=10,5
import warnings
warnings.filterwarnings("ignore")

# %%
stats2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
###Distribution:
sns.distplot(stats2.InternetUsers)
plt.show()

# %%
vis1 = sns.distplot(stats2["InternetUsers"])

# %%
vis1 = sns.distplot(stats2["InternetUsers"], bins=30)

# %%
#Boxplots
vis2 = sns.boxplot(data=stats2, x="IncomeGroup", y="BirthRate")

# %%
#Seaborn Gallery http://seaborn.pydata.org/examples/timeseries_from_dataframe.html

# %%
vis3 = sns.lmplot(data=stats2,x="InternetUsers",y="BirthRate", fit_reg=False)

# %%
vis3 = sns.lmplot(data=stats2,x="InternetUsers",y="BirthRate", fit_reg=False, \
                 hue="IncomeGroup", size=10, aspect=1)
